# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# 1. Data Collection & Exploration

# %%
data_train_path = '../Fruits_Vegetables/train'
data_test_path = '../Fruits_Vegetables/test'
data_validation_path = '../Fruits_Vegetables/validation'

# %%
img_width = 180
img_height = 180
#Using TensorFlow's `image_dataset_from_directory` function to create a dataset of images for training a machine learning model. 
data_train  = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (img_width,img_height),
    batch_size = 32,
    validation_split = False 
)
# Out:
# Found 3115 files belonging to 36 classes.

# %%
data_category = data_train.class_names
data_category
#These are the classes to which the images belong.
# Out:
# ['apple',
#  'banana',
#  'beetroot',
#  'bell pepper',
#  'cabbage',
#  'capsicum',
#  'carrot',
#  'cauliflower',
#  'chilli pepper',
#  'corn',
#  'cucumber',
#  'eggplant',
#  'garlic',
#  'ginger',
#  'grapes',
#  'jalepeno',
#  'kiwi',
#  'lemon',
#  'lettuce',
#  'mango',
#  'onion',
#  'orange',
#  'paprika',
#  'pear',
#  'peas',
#  'pineapple',
#  'pomegranate',
#  'potato',
#  'raddish',
#  'soy beans',
#  'spinach',
#  'sweetcorn',
#  'sweetpotato',
#  'tomato',
#  'turnip',
#  'watermelon']

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_validation_path,
    shuffle = False,
    image_size = (img_width,img_height),
    batch_size = 32,
    validation_split = False 
    )
# Out:
# Found 351 files belonging to 36 classes.

# %%
data_test  =tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle = False,
    image_size = (img_width,img_height),
    batch_size = 32,
    validation_split = False
)
# Out:
# Found 359 files belonging to 36 classes.

# %%
#Iterates through the first batch of images and label in the `data_train` dataset. For each image in the batch, plot a 3x3 grid of subplots and display the image along with its corresponding label from the `data_category` dictionary. The images are converted to numpy arrays and displayed as uint8 data type.
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_category[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# 2. Data preprocessing

# %%
rescale = Sequential([
    layers.Rescaling(1./255),
])

augmentation = Sequential([
    layers.RandomFlip("horizontal_and_vertical")
    #layers.RandomRotation(0.2)
])

# %% [markdown]
# 3. Model Development & Optimization

# %%
early_stop = EarlyStopping(
    monitor='val_accuracy',     # what to watch
    patience=5,             # epochs to wait
    restore_best_weights=True
)

# %%
model = Sequential([
    rescale,
    layers.Conv2D(16,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3,padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_category))
])

# %%
model.compile(optimizer='adam',loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 50
history = model.fit(data_train,validation_data=data_val, epochs=epochs_size, callbacks=[early_stop])
# Out:
# Epoch 1/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 396ms/step - accuracy: 0.8815 - loss: 0.4350 - val_accuracy: 0.9117 - val_loss: 0.4323
# Epoch 2/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 390ms/step - accuracy: 0.9124 - loss: 0.3165 - val_accuracy: 0.9430 - val_loss: 0.3866
# Epoch 3/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 47s 473ms/step - accuracy: 0.9422 - loss: 0.2320 - val_accuracy: 0.9487 - val_loss: 0.3324
# Epoch 4/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 419ms/step - accuracy: 0.9615 - loss: 0.1707 - val_accuracy: 0.9630 - val_loss: 0.3039
# Epoch 5/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 413ms/step - accuracy: 0.9762 - loss: 0.1258 - val_accuracy: 0.9630 - val_loss: 0.3233
# Epoch 6/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 45s 448ms/step - accuracy: 0.9820 - loss: 0.0949 - val_accuracy: 0.9658 - val_loss: 0.3291
# Epoch 7/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 361ms/step - accuracy: 0.9817 - loss: 0.0985 - val_accuracy: 0.9715 - val_loss: 0.3063
# Epoch 8/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 370ms/step - accuracy: 0.9743 - loss: 0.1270 - val_accuracy: 0.9601 - val_loss: 0.3392
# Epoch 9/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 373ms/step - accuracy: 0.9852 - loss: 0.0932 - val_accuracy: 0.9658 - val_loss: 0.2932
# Epoch 10/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 365ms/step - accuracy: 0.9839 - loss: 0.0801 - val_accuracy: 0.9601 - val_loss: 0.3694
# Epoch 11/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 370ms/step - accuracy: 0.9846 - loss: 0.0779 - val_accuracy: 0.9601 - val_loss: 0.3036
# Epoch 12/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 393ms/step - accuracy: 0.9843 - loss: 0.0720 - val_accuracy: 0.9573 - val_loss: 0.3266
# Epoch 13/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 411ms/step - accuracy: 0.9839 - loss: 0.0833 - val_accuracy: 0.9630 - val_loss: 0.2900
# Epoch 14/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 428ms/step - accuracy: 0.9859 - loss: 0.0626 - val_accuracy: 0.9630 - val_loss: 0.3455
# Epoch 15/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 381ms/step - accuracy: 0.9868 - loss: 0.0620 - val_accuracy: 0.9658 - val_loss: 0.3134
# Epoch 16/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 393ms/step - accuracy: 0.9881 - loss: 0.0484 - val_accuracy: 0.9544 - val_loss: 0.3509
# Epoch 17/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 45s 456ms/step - accuracy: 0.9884 - loss: 0.0515 - val_accuracy: 0.9658 - val_loss: 0.3073
# Epoch 18/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 42s 421ms/step - accuracy: 0.9872 - loss: 0.0449 - val_accuracy: 0.9630 - val_loss: 0.3162
# Epoch 19/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 415ms/step - accuracy: 0.9872 - loss: 0.0476 - val_accuracy: 0.9601 - val_loss: 0.3094
# Epoch 20/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 41s 402ms/step - accuracy: 0.9881 - loss: 0.0476 - val_accuracy: 0.9630 - val_loss: 0.3100
# Epoch 21/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 405ms/step - accuracy: 0.9872 - loss: 0.0485 - val_accuracy: 0.9601 - val_loss: 0.4013
# Epoch 22/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 43s 432ms/step - accuracy: 0.9878 - loss: 0.0455 - val_accuracy: 0.9601 - val_loss: 0.3577
# Epoch 23/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 402ms/step - accuracy: 0.9888 - loss: 0.0395 - val_accuracy: 0.9402 - val_loss: 0.5909
# Epoch 24/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 393ms/step - accuracy: 0.9759 - loss: 0.0795 - val_accuracy: 0.9516 - val_loss: 0.4101
# Epoch 25/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 383ms/step - accuracy: 0.9563 - loss: 0.1411 - val_accuracy: 0.9516 - val_loss: 0.4151
# Epoch 26/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 389ms/step - accuracy: 0.9621 - loss: 0.1309 - val_accuracy: 0.9459 - val_loss: 0.4670
# Epoch 27/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 40s 400ms/step - accuracy: 0.9701 - loss: 0.0971 - val_accuracy: 0.9459 - val_loss: 0.4617
# Epoch 28/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 391ms/step - accuracy: 0.9602 - loss: 0.1472 - val_accuracy: 0.9573 - val_loss: 0.3606
# Epoch 29/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 378ms/step - accuracy: 0.9737 - loss: 0.0908 - val_accuracy: 0.9544 - val_loss: 0.4098
# Epoch 30/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 388ms/step - accuracy: 0.9817 - loss: 0.0591 - val_accuracy: 0.9601 - val_loss: 0.3246
# Epoch 31/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 385ms/step - accuracy: 0.9836 - loss: 0.0523 - val_accuracy: 0.9601 - val_loss: 0.4195
# Epoch 32/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 398ms/step - accuracy: 0.9836 - loss: 0.0603 - val_accuracy: 0.9658 - val_loss: 0.3647
# Epoch 33/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 354ms/step - accuracy: 0.9872 - loss: 0.0398 - val_accuracy: 0.9630 - val_loss: 0.3839
# Epoch 34/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 37s 371ms/step - accuracy: 0.9859 - loss: 0.0489 - val_accuracy: 0.9658 - val_loss: 0.3786
# Epoch 35/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 39s 393ms/step - accuracy: 0.9865 - loss: 0.0405 - val_accuracy: 0.9630 - val_loss: 0.4090
# Epoch 36/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 38s 389ms/step - accuracy: 0.9888 - loss: 0.0398 - val_accuracy: 0.9658 - val_loss: 0.3720
# Epoch 37/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 363ms/step - accuracy: 0.9894 - loss: 0.0334 - val_accuracy: 0.9601 - val_loss: 0.4044
# Epoch 38/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 358ms/step - accuracy: 0.9875 - loss: 0.0393 - val_accuracy: 0.9630 - val_loss: 0.4487
# Epoch 39/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 349ms/step - accuracy: 0.9868 - loss: 0.0374 - val_accuracy: 0.9630 - val_loss: 0.4016
# Epoch 40/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 349ms/step - accuracy: 0.9865 - loss: 0.0404 - val_accuracy: 0.9630 - val_loss: 0.4549
# Epoch 41/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 359ms/step - accuracy: 0.9852 - loss: 0.0433 - val_accuracy: 0.9601 - val_loss: 0.5197
# Epoch 42/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 353ms/step - accuracy: 0.9856 - loss: 0.0472 - val_accuracy: 0.9630 - val_loss: 0.4266
# Epoch 43/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 364ms/step - accuracy: 0.9884 - loss: 0.0335 - val_accuracy: 0.9573 - val_loss: 0.4664
# Epoch 44/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 366ms/step - accuracy: 0.9839 - loss: 0.0578 - val_accuracy: 0.9487 - val_loss: 0.4542
# Epoch 45/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 353ms/step - accuracy: 0.9843 - loss: 0.0468 - val_accuracy: 0.9630 - val_loss: 0.4266
# Epoch 46/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 357ms/step - accuracy: 0.9881 - loss: 0.0446 - val_accuracy: 0.9630 - val_loss: 0.4779
# Epoch 47/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 353ms/step - accuracy: 0.9833 - loss: 0.0532 - val_accuracy: 0.9544 - val_loss: 0.4965
# Epoch 48/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 355ms/step - accuracy: 0.9849 - loss: 0.0512 - val_accuracy: 0.9601 - val_loss: 0.4467
# Epoch 49/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 35s 353ms/step - accuracy: 0.9856 - loss: 0.0552 - val_accuracy: 0.9573 - val_loss: 0.4243
# Epoch 50/50
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 36s 360ms/step - accuracy: 0.9795 - loss: 0.0717 - val_accuracy: 0.9630 - val_loss: 0.4356

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label='Training Accuracy',color='red')
plt.plot(epochs_range,history.history['val_accuracy'],label="Validation Accuracy")
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label='Training Loss')
plt.plot(epochs_range,history.history['val_loss'],label="Validation Loss")
plt.title('Loss')
plt.show()

# %%
import numpy as np
from tensorflow.keras.models import load_model 

# true labels and prediction scores from the test set
y_true = []
y_pred_scores = []

# iterating over the test dataset
for images, labels in data_test:
    y_true.extend(labels.numpy())
    y_pred_scores.extend(model.predict(images)) 

# Convert lists to NumPy arrays
y_true = np.array(y_true)
y_pred_scores = np.array(y_pred_scores)
y_pred = np.argmax(y_pred_scores, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

print("--- Classification Report ---".center(65))
print(classification_report(y_true, y_pred, target_names=data_category))

#confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix 
plt.figure(figsize=(10, 10)) 
sns.heatmap(cm, annot=False,  cmap='Blues', xticklabels=data_category, yticklabels=data_category)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
#                   --- Classification Report ---
#                precision    recall  f1-score   support
#
#         apple       0.64      0.70      0.67        10
#        banana       1.00      0.67      0.80         9
#      beetroot       0.83      1.00      0.91        10
#   bell pepper       0.64      0.90      0.75        10
#       cabbage       0.71      1.00      0.83        10
#      capsicum       0.90      0.90      0.90        10
#        carrot       0.90      0.90      0.90        10
#   cauliflower       1.00      0.70      0.82        10
# chilli pepper       1.00      0.60      0.75        10
#          corn       0.75      0.90      0.82        10
#      cucumber       0.62      1.00      0.77        10
#      eggplant       1.00      1.00      1.00        10
#        garlic       1.00      1.00      1.00        10
#        ginger       1.00      0.90      0.95        10
#        grapes       1.00      0.90      0.95        10
#      jalepeno       1.00      0.50      0.67        10
#          kiwi       0.77      1.00      0.87        10
#         lemon       1.00      0.80      0.89        10
#       lettuce       1.00      0.60      0.75        10
#         mango       1.00      1.00      1.00        10
#         onion       1.00      0.90      0.95        10
#        orange       0.83      1.00      0.91        10
#       paprika       1.00      0.90      0.95        10
#          pear       1.00      1.00      1.00        10
#          peas       1.00      0.80      0.89        10
#     pineapple       0.83      1.00      0.91        10
#   pomegranate       0.71      1.00      0.83        10
#        potato       1.00      0.60      0.75        10
#       raddish       1.00      0.80      0.89        10
#     soy beans       0.82      0.90      0.86        10
#       spinach       0.60      0.90      0.72        10
#     sweetcorn       0.89      0.80      0.84        10
#   sweetpotato       0.89      0.80      0.84        10
#        tomato       1.00      0.90      0.95        10
#        turnip       0.91      1.00      0.95        10
#    watermelon       1.00      0.90      0.95        10
#
#      accuracy                           0.87       359
#     macro avg       0.90      0.87      0.87       359
#  weighted avg       0.90      0.87      0.87       359

# %% [markdown]
# Testing

# %%
image = 'Image_6.JPG'
image = tf.keras.utils.load_img(image, target_size=(img_height,img_width))
img_arr = tf.keras.utils.img_to_array(image)
img_bat = tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step

# %%
score = tf.nn.softmax(predict)
print('The image is {} with accuracy of {:0.2f}'.format(data_category[np.argmax(score)],np.max(score)*100))
# Out:
# The image is apple with accuracy of 99.89

# %% [markdown]
# Model export for deployment

# %%
model.save('Image_classifier.keras')
